# %%
import os
import pandas as pd

#origen = r"C:\Users\RGARCIA\Downloads\00 Metadatas\Indux\251215"
origen = r"C:\Users\RGARCIA\Downloads\SAT 2020\Operaciones\2025 XML\Recibidos\Metadata"

def unir_txt_a_excel(directorio, archivo_salida):
    todos_los_datos = []

    for archivo in os.listdir(directorio):
        if archivo.endswith('.txt'):
            ruta_archivo = os.path.join(directorio, archivo)
            
            # Leer archivo con separador "~"
            df = pd.read_csv(ruta_archivo, delimiter='~', header=0, encoding='utf-8')
            
            # Agregar columna con nombre del archivo
            df['Archivo'] = archivo
            todos_los_datos.append(df)

    df_final = pd.concat(todos_los_datos, ignore_index=True)

    # Convertir columnas 'Estatus' y 'Monto' a numérico
    if 'Estatus' in df_final.columns:
        df_final['Estatus'] = pd.to_numeric(df_final['Estatus'], errors='coerce')
    if 'Monto' in df_final.columns:
        df_final['Monto'] = pd.to_numeric(df_final['Monto'], errors='coerce')

    # Ordenar por la columna 'FechaEmision' (ascendente)
    if 'FechaEmision' in df_final.columns:
        df_final = df_final.sort_values(by='FechaEmision', ascending=True)

    # Exportar a Excel
    df_final.to_excel(archivo_salida, sheet_name='Unidos', index=False)
    print(f"Archivo Excel '{archivo_salida}' generado exitosamente.")

# Ejecutar función
directorio_txt = origen
archivo_excel_salida = fr"{origen}\Metadata.xlsx"

unir_txt_a_excel(directorio_txt, archivo_excel_salida)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#
# ...
